# %%
from indicators import indicator_map
# %matplotlib inline

# %%
cat = 'Environment'
sub_cat = 'Emissions'
keyword = 'CO2'

# %%
m = indicator_map()
# Out:
# Fetching data from gdoc... OK  0.53s
# Convert to numeric... OK  0.02s
# Mapping data... OK  0.01s

# %%
m.make_heatmap(category=cat, annot=False)

# %%
m.make_tagcloud(category=cat)

# %%
SC = m.get_subcategories(category=cat)
print(SC)
# Out:
# ['Air pollution' 'Ozone' 'Emissions' 'Noise' 'Biodiversity' 'Ecosystems'
#  'Acidification' 'Toxicity' 'Oceans' 'Resources']

# %%
m.make_tagcloud(category=cat, subcategory=sub_cat)

# %%
table = m.get_indicator(category=cat, subcategory=sub_cat, keyword=keyword)
table
# Out:
#                                                                  Indicator
# Category    Subcategory
# Environment Emissions                      Annual CO2 emissions per capita
#             Emissions            Total CO2 emissions, in tonnes per head.
#             Emissions                                         CO2 emission
#             Emissions    Annual direct CO2 emissions of residential sec...
#             Emissions    Demand-based CO2 productivity Real income per ...
#             Emissions                      Total CO2 equivalent per capita
#             Emissions               CO2 emissions per capita (tCO2/capita)
#             Emissions    Total energy and industry-related GHG emission...
#             Emissions                   CO2 emissions, total and by sector
#             Emissions    Annual direct industrial CO2 emissions release...
#             Emissions             CO2 emission intensities per unit of GDP
#             Emissions    Production-based CO2 productivity GDP per unit...
#             Emissions                  CO2 emissions/GDP, PPP (tCO2/'000$)
#             Emissions    Total CO2 emissions, in grams per unit of real...
#             Emissions                                        CO2 intensity
#             Emissions    Global Climate equivalent (GCeq) = total green...
#             Emissions    An assessment of the ambitiousness of CO2 emis...

# %%
table.to_excel('table.xlsx')
